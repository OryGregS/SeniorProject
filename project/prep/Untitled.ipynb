# %%
import pandas as pd

# %%
master = pd.read_csv('../data/contact_master.csv')

# %%
match = pd.read_csv('../data/contact_match.csv')

# %%
master.head()
# Out:
#                           LAST_NAME MIDDLE_NAME           FIRST_NAME  \
# 0  Chamberlain/Lehnhardt/Ruboyianes         NaN  Scott/Robert/Andrew
# 1                         Moorehead       Irene              Janetta
# 2                           Brucato     Cathlyn               Regina
# 3                           McGuirk     Francsi                James
# 4                            Peluso       Marie               Elaine
#
#                     FIRM_NAME                 OFFICE_NAME  \
# 0  UBS Financial Services Inc  UBS Financial Services Inc
# 1  UBS Financial Services Inc  UBS Financial Services Inc
# 2  UBS Financial Services Inc  UBS Financial Services Inc
# 3  UBS Financial Services Inc  UBS Financial Services Inc
# 4  UBS Financial Services Inc  UBS Financial Services Inc
#
#                EMAIL_ADDRESS  BUSINESS_PHONE  \
# 0                        NaN             NaN
# 1  janetta.moorehead@ubs.com  (800) 754-5670
# 2      nikki.brucato@ubs.com  (310) 772-8062
# ...

# %%
master.dtypes
# Out:
# LAST_NAME          object
# MIDDLE_NAME        object
# FIRST_NAME         object
# FIRM_NAME          object
# OFFICE_NAME        object
# EMAIL_ADDRESS      object
# BUSINESS_PHONE     object
# ADDRESS_LINE_1     object
# ADDRESS_LINE_2     object
# CITY               object
# STATE_PROVINCE     object
# POSTAL_CODE_1      object
# POSTAL_CODE_2     float64
# COUNTRY_ID         object
# CRD_NUMBER        float64
# CONTACT_ID         object
# dtype: object

# %%
self.datasets[i]
