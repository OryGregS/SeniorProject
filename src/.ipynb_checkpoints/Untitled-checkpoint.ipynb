# %%
import pandas as pd

# %%
master = pd.read_csv("../data/master.csv", error_bad_lines=False, engine='python', warn_bad_lines=False)
match = pd.read_csv("../data/match.csv", error_bad_lines=False, engine='python', warn_bad_lines=False)

master = master.astype('str')
match = match.astype('str')

master = master.replace('nan', '')
match = match.replace('nan', '')

# %%
match.head()
master.iloc[3,7]
# Out:
# '300 BSoadhoMMow Sd SUe 303'

# %%
master.head()
# Out:
#     LAST_NAME MIDDLE_NAME    FIRST_NAME  FIRM_NAME  OFFICE_NAME  \
# 0     ZDDouOU              CSZOcI Iouse  TEST_FIRM  TEST_OFFICE
# 1  GZSUeOIZus           S        IowZSE  TEST_FIRM  TEST_OFFICE
# 2   SUeiODeSg           C         ZMWiO  TEST_FIRM  TEST_OFFICE
# 3  MZSiOZDDio        KoIO        KoseQI  TEST_FIRM  TEST_OFFICE
# 4       Zmiss           C          EASZ  TEST_FIRM  TEST_OFFICE
#
#                   EMAIL_ADDRESS  BUSINESS_PHONE              ADDRESS_LINE_1  \
# 0                                (309) 373-5307             330 E HowaSd SU
# 1    IowZSE.gZSUeOIZus@ZmQG.com  (300) 770-5505  3500 SeseaSch BMWd SUe 000
# 2    ZMWiO.c.sUeiOCeSg@ZmQG.com  (900) 303-7935    5000 QoQMaS AWe SUe 3700
# 3  KoseQI.K.mZSiOZccio@ZmQG.com  (730) 793-5570  300 BSoadhoMMow Sd SUe 303
# 4           eZSZ.Zmiss@ZmQG.com  (550) 777-5757   3975 CoMoOOade DS SUe 330
#
#   ADDRESS_LINE_2 ADDRESS_LINE_3       CITY STATE_PROVINCE POSTAL_CODE_1  \
# ...

# %%
# Out:
# LAST_NAME         object
# MIDDLE_NAME       object
# FIRST_NAME        object
# FIRM_NAME         object
# OFFICE_NAME       object
# EMAIL_ADDRESS     object
# BUSINESS_PHONE    object
# ADDRESS_LINE_1    object
# ADDRESS_LINE_2    object
# ADDRESS_LINE_3    object
# CITY              object
# STATE_PROVINCE    object
# POSTAL_CODE_1     object
# POSTAL_CODE_2     object
# COUNTRY_ID        object
# CRD_NUMBER        object
# CONTACT_ID        object
# dtype: object
